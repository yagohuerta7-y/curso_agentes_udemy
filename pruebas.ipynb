# %%
import os
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI

# %%
# Cargamos la variable de entorno de la api key
load_dotenv()

# Asignamos la api key a la variable de entorno
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

# Definimos el modelo
llm = ChatOpenAI(model="gpt-5-nano-2025-08-07", temperature=0.0, api_key=OPENAI_API_KEY)

# %%
# Guardamos la pregunta en unna variable
pregunta = "Explícame las direncias entre la inntegral de Riemann y la de Lebesgue"

# Hacemos la inferencia
respuesta = llm.invoke(pregunta)

# %%
print(respuesta.content)
# Out:
# ¡Claro! Aquí tienes una explicación clara de las diferencias entre la integral de Riemann y la integral de Lebesgue, con ideas y ejemplos.
#
# Qué intenta hacer cada una
# - Integral de Riemann: aproxima la integral dividiendo el eje x (el dominio) en intervalos y sumando “áreas” de rectángulos cuyas bases son esos intervalos y alturas toman valores dentro de cada subintervalo (basado en el dominio).
# - Integral de Lebesgue: aproxima la integral agrupando por valores de la función (nivel o nivelación de y), midiendo cuánta “masa” (con medida) corresponde a cada rango de valores de la función y sumando esas contribuciones.
#
# Definiciones muy esquemáticas
# - Riemann:
#   - Dada f: [a,b] -> R (generalmente acotada). Para una partición P del dominio, se construyen sumas superiores e inferiores usando, en cada subintervalo, el supremo o ínfimo de f allí. Si, al refinar las particiones (malla tiende a 0), la cota superior y la cota inferior convergen a la misma cantidad, esa cantidad es la integral de Riemann.
# - Lebesgue:
#   - Trabaja con funciones medibles y la medida (en [a,b], la medida de Lebesgue). Para f ≥ 0, la integral se define como el sup de las integrales de funciones simples s ≤ f (donde las simples toman valores finitos y son constantes en conjuntos medibles). Para f en general, se descompone en partes positiva y negativa y se resta. Una forma útil para f ≥ 0: ∫ f = sup ∑ α_i μ(A_i) para simples s = ∑ α_i 1_{A_i} con s ≤ f.
#
# Intuición importante
# - Riemann: la integral se entiende a través de particiones del eje X. Es decir, el dominio se “corta” en intervalos y se estima el área por encima/debajo de f en cada intervalo.
# - Lebesgue: la integral se entiende a través de la medida de cuántas x satisfacen que f(x) esté en cierto rango de valores. Es como “particionar por valores de la función” en lugar de por dónde cae cada x.
#
# Cuáles son las diferencias clave
# 1) Qué se requiere de la función
# - Riemann: f debe ser acotada en [a,b]. En general, f debe ser acotada para que tenga sentido la construcción clásica. Además, la condición práctica es que el conjunto de discontinuidades de f tenga medida cero.
# - Lebesgue: f debe ser medible (con respecto a la Lebesgue). Puede ser acotada o no; para que la integral exista de forma finita se suele exigir ∫|f| < ∞ (integrable en sentido Lebesgue).
#
# 2) Qué garantiza la integrabilidad
# - Riemann: f es integrable si las sumas superiores e inferiores convergen a la misma cantidad. Esto suele ocurrir si f es acotada y sus discontinuidades son “pocas” (con medida cero).
# - Lebesgue: f es integrable (en el sentido usual) si ∫|f| < ∞. Hay muchas funciones que no son Riemann integrables pero sí Lebesgue integrables, gracias a la flexibilidad de medir por niveles.
#
# 3) Funciones que se pueden integrar
# - Función típica que no es Riemann integrable pero sí Lebesgue: la función indicadora de los racionales en [0,1], 1_Q.
#   - Por Riemann: no es integrable, porque en cada subintervalo hay racionales e irracionales, de modo que el supremo es 1 y el ínfimo es 0; las sumas no convergen a un valor único.
#   - Por Lebesgue: sí es integrable y su integral es 0, porque los racionales tienen medida 0.
# - En cambio, cualquier función que sea Riemann integrable ya lo es Lebesgue y dan el mismo valor de la integral.
#
# 4) Propiedades útiles y teoremas de convergencia
# - Lebesgue: existen teoremas potentes como la convergencia monotona (MCT) y la convergencia dominada (DCT), que permiten intercambiar límites y integrales en gran cantidad de situaciones.
# - Riemann: no tiene una teoría de convergencia tan robusta; para problemas de límites de integrales, a menudo se requieren técnicas más complicadas.
#
# 5) Relaciones entre ambas integralas
# - Si una función f es Riemann integrable en [a,b], entonces es Lebesgue integrable y ambas integrales coinciden.
# - La integral de Lebesgue es una generalización: extiende la clase de funciones que se pueden integrar y conserva muchas propiedades útiles.
#
# Ejemplos ilustrativos
# - Dirichlet (indicadora de los racionales): f(x) =
#   - 1 si x es racional, 0 si x es irracional, en [0,1].
#   - Riemann: no es integrable (discontinuidad en cada punto).
#   - Lebesgue: integrable y ∫ f = μ({x: f(x)=1}) = μ(Q ∩ [0,1]) = 0, porque los racionales tienen medida 0.
# - Indicadora de un conjunto con medida positiva y borde “grueso” (un ejemplo conceptual de diferencia entre Lebesgue y Riemann):
#   - Si A es un conjunto cerrado con borde de medida positiva, la función 1_A puede no ser Riemann integrable (si el borde tiene medida positiva, la condición de puntos de discontinuidad de medida cero falla). En Lebesgue, ∫ 1_A dμ = μ(A) es fácil de calcular.
#
# Cuándo usar cada una
# - Integral de Riemann: suficiente para funciones bien comportadas en intervalos cerrados y acotadas; es más “geométrica” y suficiente en muchos cursos introductorios.
# - Integral de Lebesgue: más general, maneja funciones con discontinuidades densas, funciones no acotadas en conjuntos de finite medida, y facilita el uso de teoremas de convergencia (MCT, DCT). Es la base del análisis moderno, probabilidad, Fourier, etc.
#
# Resumen
# - La integral de Riemann aproxima por particiones del dominio; la de Lebesgue aproxima por niveles de la función y por la medida de esos niveles.
# - La Lebesgue es más general y poderosa: puede integrar más funciones y se comporta mejor con límites en general.
# - Si una función es Riemann integrable, su integral coincide con la integral de Lebesgue. Pero existen funciones Lebesgue integrables que no son Riemann integrables (p. ej., la función indicadora de los racionales).
#
# ¿Quieres que te explique con más detalle alguna de las definiciones (por ejemplo, la definición formal de la integral de Lebesgue o la caracterización de la integrabilidad de Riemann mediante las discontinuidades) o te muestro un par de demostraciones cortas? También puedo darte un ejemplo concreto paso a paso para ver cómo se calcula cada integral.
